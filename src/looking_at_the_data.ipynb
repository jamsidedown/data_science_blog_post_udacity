# %%
import pandas

df = pandas.read_csv('../data/survey_results_public.csv')
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
df['Age1stCode'].value_counts()
# Age first started coding affects salary
# Would need to be analysed by age?
# Out:
# 15    8681
# 16    8633
# 14    8452
# 18    7945
# 12    7735
#       ...
# 58       1
# 77       1
# 57       1
# 67       1
# 83       1
# Name: Age1stCode, Length: 69, dtype: int64

# %%
print(df['UnitTests'].value_counts())
print()
print(df['CodeRev'].value_counts())
print()
print(df['CodeRevHrs'].value_counts())
# Could look at job satisfaction in jobs where developers spend time reviewing code and writing unit tests
# Could maybe look at job satisfaction against time spent reviewing code?
# Out:
# Yes, it's part of our process                                              26221
# No, but I think we should                                                  20835
# Yes, it's not part of our process but the developers do it on their own    12828
# No, and I'm glad we don't                                                   2784
# Name: UnitTests, dtype: int64
#
# Yes, because I see value in code review    48424
# No                                         16627
# Yes, because I was told to do so            5339
# Name: CodeRev, dtype: int64
#
# 2.00     9610
# 5.00     9001
# 4.00     6552
# 3.00     5902
# 1.00     5331
#          ...
# 3.80        1
# 49.00       1
# 1.37        1
# 82.00       1
# 2.57        1
# Name: CodeRevHrs, Length: 92, dtype: int64

# %%
df['YearsCodePro'].value_counts()
# Out:
# 2                     7959
# 3                     7793
# 5                     6416
# 4                     6306
# 6                     4518
# 1                     4449
# 10                    4367
# Less than 1 year      3997
# 7                     3662
# 8                     3449
# 12                    2231
# 15                    2128
# 20                    2061
# 9                     1979
# 11                    1663
# 13                    1376
# 18                    1170
# 14                    1143
# 16                     781
# 19                     772
# 25                     732
# 22                     693
# 17                     632
# 30                     551
# 21                     549
# 23                     454
# 24                     340
# 35                     227
# 28                     223
# 27                     202
# 26                     201
# 32                     176
# 33                     136
# 29                     128
# ...

# %%
print(df['EdLevel'].value_counts())
print()
print(df['JobFactors'].value_counts())
# Out:
# Bachelor’s degree (BA, BS, B.Eng., etc.)                                              39134
# Master’s degree (MA, MS, M.Eng., MBA, etc.)                                           19569
# Some college/university study without earning a degree                                10502
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     8642
# Associate degree                                                                       2938
# Other doctoral degree (Ph.D, Ed.D., etc.)                                              2432
# Primary/elementary school                                                              1422
# Professional degree (JD, MD, etc.)                                                     1198
# I never completed any formal education                                                  553
# Name: EdLevel, dtype: int64
#
# ...

# %%
# I want to look at the factors that contribute to an employees job satisfaction,
# and the factors that contribute to employee retention.

# The Y values in these cases will be JobSat, and LastHireDate

# Although Job Satisfaction values are categorical, I'm going to convert them to
# the numerical values 1-5 in order to try to predict satisfaction from other parameters

# Given the options are on a scale of very good to very bad, I don't believe the change
# to numerical values will reduce the quality or meaning of the answers

# Developers who are not currently employed shouldn't have an answer for this, but those
# developers will be filtered out in the proprocessing stage anyway

# LastHireDate will also need a little preprocessing to convert it from categorical data
# to numerical data, and I'm going to make an assumption that all of the survey results
# were submitted around the same time

# Cases where the developer hasn't got a job, and where they are self employed will be
# removed for the purpose of this analysis, although it may be interesting to see if
# self employed developers are happier than those working for companies

# Before being able to predict any of these values, I'm going to have to see if there is
# a strong correlation between any of the input values I choose and a developer's job
# satisfaction and how long they've kept their current job

print(df['JobSat'].value_counts())
print()
print(df['LastHireDate'].value_counts())
# Out:
# Slightly satisfied                    24207
# Very satisfied                        22452
# Slightly dissatisfied                 10752
# Neither satisfied nor dissatisfied     8720
# Very dissatisfied                      4857
# Name: JobSat, dtype: int64
#
# Less than a year ago                                    25844
# 1-2 years ago                                           21365
# More than 4 years ago                                   14594
# 3-4 years ago                                           11597
# NA - I am an independent contractor or self employed     3426
# I've never had a job                                     3028
# Name: LastHireDate, dtype: int64

# %%
# I want to look at how decisions organisations make about process affect employee job
# satisfaction, and will then look at how employee satisfaction affects employee retention

# The primary decisions organisations can make that I want to factor are whether or not
# developers in organisations write unit tests as part of their job, and how much time
# developers spend reviewing code as part of their job

# It may also be worth adding developer salary into this analysis, as I imagine being
# underpaid will contribute to dissatisfaction in developers

# One of assumptions I'm making here is that if a developer spends time reviewing code, 
# the rest of their team likely spends a similar amount of time also reviewing code

# It's my hypothesis that developers in organisations that write unit tests and review
# everyone's code will more confidence in their code, and less day to day stresses

# I will look for a correlation between these practices and job satisfaction in order to
# assess this hypothesis
